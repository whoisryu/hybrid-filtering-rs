# %%
import pandas as pd

# %%
df_rat = pd.read_csv("./ml-25m/ratings.csv")
df_mov = pd.read_csv("./ml-25m/movies.csv")

# %%
df_desc = pd.read_csv("./description-final.csv")

# %%
df_desc
# Out:
#                                        title  \
# 0                      Waiting for Lightning
# 1                          Yesterday's Enemy
# 2                               Young People
# 3                                      Henry
# 4                                 L'incruste
# ...                                      ...
# 43322                                    Wij
# 43323                         Janela da Alma
# 43324                           Rossz versek
# 43325                           A Girl Thing
# 43326  Le prigioniere dell'isola del diavolo
#
#                                              description  movieId
# 0      A documentary on pro skateboarder Danny Way's ...    99513
# 1      In World War II, during the Japanese invasion ...    99515
# 2      A show-business family leaves the Great White ...    99517
# 3      Henry is a cynical man who owns a musical inst...    99519
# 4      A small crook manages to crash at a musician's...    99521
# ...

# %%
df_desc = pd.merge(df_desc, df_mov, on='movieId', how='left')

# %%
df_desc.drop(['title_x', 'title_y_'])
df_desc
# Out:
#                                      title_x  \
# 0                      Waiting for Lightning
# 1                          Yesterday's Enemy
# 2                               Young People
# 3                                      Henry
# 4                                 L'incruste
# ...                                      ...
# 43322                                    Wij
# 43323                         Janela da Alma
# 43324                           Rossz versek
# 43325                           A Girl Thing
# 43326  Le prigioniere dell'isola del diavolo
#
#                                              description  movieId  \
# 0      A documentary on pro skateboarder Danny Way's ...    99513
# 1      In World War II, during the Japanese invasion ...    99515
# 2      A show-business family leaves the Great White ...    99517
# 3      Henry is a cynical man who owns a musical inst...    99519
# 4      A small crook manages to crash at a musician's...    99521
# ...

# %%
df_desc = df_desc.dropna()

# %%
df_desc['D'] = df_desc.apply(lambda x: '_'.join(x.astype(str)), axis=1)

# %%
df_desc
# Out:
#                                      title_x  \
# 0                      Waiting for Lightning
# 1                          Yesterday's Enemy
# 2                               Young People
# 3                                      Henry
# 4                                 L'incruste
# ...                                      ...
# 43322                                    Wij
# 43323                         Janela da Alma
# 43324                           Rossz versek
# 43325                           A Girl Thing
# 43326  Le prigioniere dell'isola del diavolo
#
#                                              description  movieId  \
# 0      A documentary on pro skateboarder Danny Way's ...    99513
# 1      In World War II, during the Japanese invasion ...    99515
# 2      A show-business family leaves the Great White ...    99517
# 3      Henry is a cynical man who owns a musical inst...    99519
# 4      A small crook manages to crash at a musician's...    99521
# ...

# %%
df_mov
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df_desc
# Out:
#                                        title  \
# 0                      Waiting for Lightning
# 1                          Yesterday's Enemy
# 2                               Young People
# 3                                      Henry
# 4                                 L'incruste
# ...                                      ...
# 43322                                    Wij
# 43323                         Janela da Alma
# 43324                           Rossz versek
# 43325                           A Girl Thing
# 43326  Le prigioniere dell'isola del diavolo
#
#                                              description  movieId
# 0      A documentary on pro skateboarder Danny Way's ...    99513
# 1      In World War II, during the Japanese invasion ...    99515
# 2      A show-business family leaves the Great White ...    99517
# 3      Henry is a cynical man who owns a musical inst...    99519
# 4      A small crook manages to crash at a musician's...    99521
# ...

# %%
df_rat_mov = pd.merge(df_rat, df_desc, on="movieId", how="inner")

# %%
df_rat_mov =df_rat_mov.sort_values(by='userId', ascending=True)
df_rat_mov
# Out:
#          userId  movieId  rating   timestamp  \
# 0             3   101864     4.0  1439474698
# 498249        3   135536     3.5  1566090614
# 493840        3   135143     3.5  1566090422
# 489790        3   135133     3.5  1484755332
# 476210        3   134853     4.0  1439472519
# ...         ...      ...     ...         ...
# 18249    162538   102407     3.5  1438785482
# 895069   162538   126548     4.0  1438784697
# 355693   162538   116797     4.5  1438781121
# 277536   162538   112556     3.5  1438784733
# 1110682  162538   102993     4.5  1438785297
#
#                                            title  \
# 0                                       Oblivion
# 498249                             Suicide Squad
# 493840   Fantastic Beasts and Where to Find Them
# 489790     The Hunger Games: Mockingjay - Part 2
# 476210                                Inside Out
# ...                                          ...
# 18249                           The Great Gatsby
# ...

# %%
df_rat_mov_3 = df_rat_mov[df_rat_mov['userId'] == 3]

# %%
df_rat_mov_3 = df_rat_mov_3.sort_values(by='rating', ascending=False)
df_rat_mov_3
# Out:
#         userId  movieId  rating   timestamp                            title  \
# 253540       3   112552     5.0  1439472513                         Whiplash
# 507784       3   136449     5.0  1484753762               Kôkaku kidôtai 2.0
# 264719       3   112556     5.0  1439473517                        Gone Girl
# 327627       3   115713     4.5  1439474672                       Ex Machina
# 581873       3   176371     4.5  1566090291                Blade Runner 2049
# ...        ...      ...     ...         ...                              ...
# 83544        3   105213     3.0  1566091330                          Don Jon
# 590299       3   182823     3.0  1566089510                           Bright
# 101129       3   106487     3.0  1439473752  The Hunger Games: Catching Fire
# 29762        3   102880     3.0  1439474833                      After Earth
# 212350       3   111113     2.5  1566091177                        Neighbors
#
# ...

# %%
df_rat_mov_3 = df_rat_mov_3[:100]

# %%
df_rat_mov_3.head(20)
# Out:
#         userId  movieId  rating   timestamp                       title  \
# 253540       3   112552     5.0  1439472513                    Whiplash
# 507784       3   136449     5.0  1484753762          Kôkaku kidôtai 2.0
# 264719       3   112556     5.0  1439473517                   Gone Girl
# 327627       3   115713     4.5  1439474672                  Ex Machina
# 581873       3   176371     4.5  1566090291           Blade Runner 2049
# 118851       3   106782     4.5  1439473659     The Wolf of Wall Street
# 68805        3   104243     4.5  1439474932                     Riddick
# 594096       3   187593     4.5  1566090414                  Deadpool 2
# 214371       3   111360     4.0  1439474812                        Lucy
# 134583       3   106920     4.0  1439473802                         Her
# 163815       3   109374     4.0  1439473513    The Grand Budapest Hotel
# 85343        3   106002     4.0  1439475028                Ender's Game
# ...

# %%
df_user_1 = pd.DataFrame(columns=['Action','Adventure','Animation',"Children's", "Comedy", "Crime","Documentary","Drama","Fantasy","Film-Noir","Horror","Musical","Mystery","Romance","Sci-Fi","Thriller","War","Western"])
df_user_1
# Out:
# Empty DataFrame
# Columns: [Action, Adventure, Animation, Children's, Comedy, Crime, Documentary, Drama, Fantasy, Film-Noir, Horror, Musical, Mystery, Romance, Sci-Fi, Thriller, War, Western]
# Index: []

# %%
for index, movie in df_rat_mov.iterrows():
    Action=0
    Adventure=0
    Animation=0
    Children=0
    Comedy=0
    Crime=0
    Documentary=0
    Drama=0
    Fantasy=0
    FilmNoir=0
    Horror=0
    Musical=0
    Mystery=0
    Romance=0
    SciFi=0
    Thriller=0
    War=0
    Western=0

    genres = movie['genres']

    if 'Action' in genres:
        Action=1
    if 'Adventures' in genres:
        Adventure=1
    if 'Animation' in genres:
        Animation=1
    if "Children's" in genres:
        Children=1
    if 'Comedy' in genres:
        Comedy=1
    if 'Crime' in genres:
        Crime=1
    if 'Documentary' in genres:
        Documentary=1
    if 'Drama' in genres:
        Drama=1
    if 'Fantasy' in genres:
        Fantasy=1
    if 'Film-Noir' in genres:
        FilmNoir=1
    if 'Horror' in genres:
        Horror=1
    if 'Musical' in genres:
        Musical=1
    if 'Mystery' in genres:
        Mystery=1
    if 'Romance' in genres:
        Romance=1
    if 'Sci-Fi' in genres:
        SciFi=1
    if 'Thriller' in genres:
        Thriller=1
    if 'War' in genres:
        War=1
    if 'Western' in genres:
        Western=1
    
    df_user_1 = df_user_1.append({
        "Action":Action,
        "Adventure": Adventure,
        "Animation": Animation,
        "Children's": Children,
        "Comedy": Comedy,
        "Crime":Crime,
        "Documentary":Documentary,
        "Drama": Drama,
        "Fantasy": Fantasy,
        "Film-Noir":FilmNoir,
        "Horror":Horror,
        "Musical": Musical,
        
    })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/aryuska/Documents/Kuliah/smt7/propo/recommendation-system/playground.ipynb Cell 13 in <cell line: 1>()
#      <a href='vscode-notebook-cell:/Users/aryuska/Documents/Kuliah/smt7/propo/recommendation-system/playground.ipynb#X15sZmlsZQ%3D%3D?line=20'>21</a> genres = movie['genres']
#      <a href='vscode-notebook-cell:/Users/aryuska/Documents/Kuliah/smt7/propo/recommendation-system/playground.ipynb#X15sZmlsZQ%3D%3D?line=22'>23</a> if 'Action' in genres:
# ---> <a href='vscode-notebook-cell:/Users/aryuska/Documents/Kuliah/smt7/propo/recommendation-system/playground.ipynb#X15sZmlsZQ%3D%3D?line=23'>24</a>     ac
#
# NameError: name 'ac' is not defined

# %%
# Out:
#   Action Adventure Animation Children's Comedy Crime Documentary Drama  \
# 0      1       NaN       NaN        NaN    NaN   NaN         NaN   NaN
#
#   Fantasy Film-Noir Horror Musical Mystery Romance Sci-Fi Thriller  War  \
# 0     NaN       NaN    NaN     NaN     NaN     NaN    NaN      NaN  NaN
#
#   Western
# 0     NaN

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

# Sample sentences
sentence1 = "The cat in the hat."
sentence2 = "The dog chased the cat."

# Tokenize sentences
set1 = set(word_tokenize(sentence1))
set2 = set(word_tokenize(sentence2))
print(set1)
# Calculate Jaccard similarity
intersection = len(set1.intersection(set2))
union = len(set1.union(set2))
jaccard_similarity = intersection / union

print(jaccard_similarity)
# Out:
# {'The', 'in', 'cat', 'hat', 'the', '.'}
# 0.5
# [nltk_data] Downloading package punkt to /Users/aryuska/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
